# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_dir = 'drive/MyDrive/DAB103/Project/'

# %%
railData = pd.read_csv(project_dir+'RODSdb_MDOTW_VW_OCCURRENCE_PUBLIC.csv', low_memory=False)
railData

# railData = pd.read_csv(project_dir+ 'RailwayAccidentData.csv')
# railData
# Out:
#         OccID     OccNo  OccClassID OccClassID_DisplayEng  \
# 0      132852  R23S0008           5                     5
# 1      132851  R23W0005           5                     5
# 2      132850  R23V0005           5                     5
# 3      132849  R23C0001           5                     5
# 4      132848  R23W0004           5                     5
# ...       ...       ...         ...                   ...
# 66334   27798  R83T2982          11                   NaN
# 66335   27797  R83C1575          11                   NaN
# 66336   27796  R83M0558          11                   NaN
# 66337   27795  R83M0557          11                   NaN
# 66338   27794  R83T2980          11                   NaN
#
#       OccClassID_DisplayFre               OccDate  OccYear  OccTime  \
# 0                         5   1/7/2023 6:50:00 AM     2023    650.0
# 1                         5   1/9/2023 6:49:00 AM     2023    649.0
# 2                         5   1/9/2023 3:35:00 PM     2023   1535.0
# 3                         5  1/5/2023 11:43:00 PM     2023   2343.0
# 4                         5   1/8/2023 5:55:00 PM     2023   1755.0
# ...                     ...                   ...      ...      ...
# 66334                   S/O  1/3/1983 12:00:00 AM     1983      0.0
# 66335                   S/O  1/3/1983 12:00:00 AM     1983   1110.0
# 66336                   S/O  1/3/1983 12:00:00 AM     1983   1552.0
# 66337                   S/O  1/2/1983 12:00:00 AM     1983   1415.0
# 66338                   S/O  1/2/1983 12:00:00 AM     1983   1203.0
#
#        TimeZoneID TimeZoneID_DisplayEng  ... SignConditionID_DisplayEng  \
# 0            11.0                   CST  ...                        NaN
# 1            11.0                   CST  ...                        NaN
# 2             7.0                   PST  ...                        NaN
# 3            10.0                   MST  ...                        NaN
# 4            11.0                   CST  ...                        NaN
# ...           ...                   ...  ...                        ...
# 66334        14.0                   NaN  ...                        NaN
# 66335        14.0                   NaN  ...                        NaN
# 66336        14.0                   NaN  ...                        NaN
# 66337        14.0                   NaN  ...                        NaN
# 66338        14.0                   NaN  ...                        NaN
#
#        SignConditionID_DisplayFre PointOfEntryID PointOfEntryID_DisplayEng  \
# 0                             NaN            NaN                       NaN
# 1                             NaN            NaN                       NaN
# 2                             NaN            NaN                       NaN
# 3                             NaN            NaN                       NaN
# 4                             NaN            NaN                       NaN
# ...                           ...            ...                       ...
# 66334                         NaN            NaN                       NaN
# 66335                         NaN            NaN                       NaN
# 66336                         NaN            NaN                       NaN
# 66337                         NaN            NaN                       NaN
# 66338                         NaN            NaN                       NaN
#
#        PointOfEntryID_DisplayFre DistanceToCrossing_Miles  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 66334                        NaN                      NaN
# 66335                        NaN                      NaN
# 66336                        NaN                      NaN
# 66337                        NaN                      NaN
# 66338                        NaN                      NaN
#
#       TrespasserVehicleInvolvedInd  TrespasserVehicleTypeID  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
# ...                            ...                      ...
# 66334                          NaN                      NaN
# 66335                          NaN                      NaN
# 66336                          NaN                      NaN
# 66337                          NaN                      NaN
# 66338                          NaN                      NaN
#
#       TrespasserVehicleTypeDisplayEng TrespasserVehicleTypeDisplayFre
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 66334                             NaN                             NaN
# 66335                             NaN                             NaN
# 66336                             NaN                             NaN
# 66337                             NaN                             NaN
# 66338                             NaN                             NaN
#
# [66339 rows x 348 columns]

# %%
railData.head()
# Out:
#     OccID     OccNo  OccClassID OccClassID_DisplayEng OccClassID_DisplayFre  \
# 0  132852  R23S0008           5                     5                     5
# 1  132851  R23W0005           5                     5                     5
# 2  132850  R23V0005           5                     5                     5
# 3  132849  R23C0001           5                     5                     5
# 4  132848  R23W0004           5                     5                     5
#
#                 OccDate  OccYear  OccTime  TimeZoneID TimeZoneID_DisplayEng  \
# 0   1/7/2023 6:50:00 AM     2023    650.0        11.0                   CST
# 1   1/9/2023 6:49:00 AM     2023    649.0        11.0                   CST
# 2   1/9/2023 3:35:00 PM     2023   1535.0         7.0                   PST
# 3  1/5/2023 11:43:00 PM     2023   2343.0        10.0                   MST
# 4   1/8/2023 5:55:00 PM     2023   1755.0        11.0                   CST
#
#    ... SignConditionID_DisplayEng  SignConditionID_DisplayFre PointOfEntryID  \
# 0  ...                        NaN                         NaN            NaN
# 1  ...                        NaN                         NaN            NaN
# 2  ...                        NaN                         NaN            NaN
# 3  ...                        NaN                         NaN            NaN
# 4  ...                        NaN                         NaN            NaN
#
#   PointOfEntryID_DisplayEng  PointOfEntryID_DisplayFre  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   DistanceToCrossing_Miles TrespasserVehicleInvolvedInd  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#    TrespasserVehicleTypeID TrespasserVehicleTypeDisplayEng  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
#   TrespasserVehicleTypeDisplayFre
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 348 columns]

# %%
railData.shape
# Out:
# (66339, 348)

# %%
railData.describe()
# Out:
#                OccID    OccClassID       OccYear       OccTime    TimeZoneID  \
# count   66339.000000  66339.000000  66339.000000  66337.000000  64524.000000
# mean    88441.465533      6.724144   2001.459534   1105.224023      8.152207
# std     33040.984740      2.525178     10.970915    715.666980      4.465585
# min     27794.000000      1.000000   1983.000000      0.000000      1.000000
# 25%     74168.000000      5.000000   1993.000000    450.000000      4.000000
# 50%     97813.000000      5.000000   2001.000000   1150.000000      8.000000
# 75%    114684.500000      9.000000   2010.000000   1700.000000     13.000000
# max    132852.000000     12.000000   2023.000000   2400.000000     14.000000
#
#        OccurrenceTypeID  AccIncTypeID  ActivityTypeID  CollistionTypeID  \
# count      66339.000000  66339.000000    64597.000000       5805.000000
# mean           1.432385     27.176442        7.471910        112.936779
# std            0.823300      8.851172        4.837492         27.015457
# min            1.000000     15.000000        1.000000          1.000000
# 25%            1.000000     20.000000        4.000000        112.000000
# 50%            1.000000     30.000000        4.000000        122.000000
# 75%            1.000000     32.000000       11.000000        122.000000
# max            3.000000     55.000000       19.000000        125.000000
#
#        NumberTrainsInvolved  ...  TresppaserNumTracks     PersonNo  \
# count          64554.000000  ...          1448.000000  1185.000000
# mean               1.081575  ...             1.164365     1.039662
# std                0.278042  ...             0.489617     0.248536
# min                0.000000  ...             1.000000     1.000000
# 25%                1.000000  ...             1.000000     1.000000
# 50%                1.000000  ...             1.000000     1.000000
# 75%                1.000000  ...             1.000000     1.000000
# max                4.000000  ...             9.000000     5.000000
#
#          FenceIND  FenceConditionID     SignIND  SignConditionID  \
# count  487.000000        237.000000  439.000000       280.000000
# mean     0.486653          3.603376    0.637813         1.257143
# std      0.500336          0.975803    0.481181         1.073442
# min      0.000000          1.000000    0.000000         1.000000
# 25%      0.000000          4.000000    0.000000         1.000000
# 50%      0.000000          4.000000    1.000000         1.000000
# 75%      1.000000          4.000000    1.000000         1.000000
# max      1.000000          4.000000    1.000000         7.000000
#
#        PointOfEntryID  DistanceToCrossing_Miles  TrespasserVehicleInvolvedInd  \
# count      400.000000                441.000000                   1496.000000
# mean         3.195000                  0.341950                      0.110294
# std          2.181484                  2.108173                      0.313361
# min          1.000000                  0.000000                      0.000000
# 25%          1.000000                  0.100000                      0.000000
# 50%          4.000000                  0.100000                      0.000000
# 75%          5.000000                  0.300000                      0.000000
# max          6.000000                 43.500000                      1.000000
#
#        TrespasserVehicleTypeID
# count               165.000000
# mean                  9.666667
# std                   5.296494
# min                   4.000000
# 25%                   4.000000
# 50%                   7.000000
# 75%                  15.000000
# max                  17.000000
#
# [8 rows x 179 columns]

# %%
railData.nunique()
# Out:
# OccID                              59928
# OccNo                              59928
# OccClassID                            11
# OccClassID_DisplayEng                 10
# OccClassID_DisplayFre                 11
#                                    ...
# DistanceToCrossing_Miles              18
# TrespasserVehicleInvolvedInd           2
# TrespasserVehicleTypeID               11
# TrespasserVehicleTypeDisplayEng       11
# TrespasserVehicleTypeDisplayFre       11
# Length: 348, dtype: int64

# %%
french_columns = [col for col in railData.columns if col.endswith("Fre")]
railDataEnglish = railData.drop(french_columns, axis=1) # removed french

# %%
railDataEnglish.shape
# Out:
# (66339, 276)

# %%
railDataEnglish.describe()
# Out:
#                OccID    OccClassID       OccYear       OccTime    TimeZoneID  \
# count   66339.000000  66339.000000  66339.000000  66337.000000  64524.000000
# mean    88441.465533      6.724144   2001.459534   1105.224023      8.152207
# std     33040.984740      2.525178     10.970915    715.666980      4.465585
# min     27794.000000      1.000000   1983.000000      0.000000      1.000000
# 25%     74168.000000      5.000000   1993.000000    450.000000      4.000000
# 50%     97813.000000      5.000000   2001.000000   1150.000000      8.000000
# 75%    114684.500000      9.000000   2010.000000   1700.000000     13.000000
# max    132852.000000     12.000000   2023.000000   2400.000000     14.000000
#
#        OccurrenceTypeID  AccIncTypeID  ActivityTypeID  CollistionTypeID  \
# count      66339.000000  66339.000000    64597.000000       5805.000000
# mean           1.432385     27.176442        7.471910        112.936779
# std            0.823300      8.851172        4.837492         27.015457
# min            1.000000     15.000000        1.000000          1.000000
# 25%            1.000000     20.000000        4.000000        112.000000
# 50%            1.000000     30.000000        4.000000        122.000000
# 75%            1.000000     32.000000       11.000000        122.000000
# max            3.000000     55.000000       19.000000        125.000000
#
#        NumberTrainsInvolved  ...  TresppaserNumTracks     PersonNo  \
# count          64554.000000  ...          1448.000000  1185.000000
# mean               1.081575  ...             1.164365     1.039662
# std                0.278042  ...             0.489617     0.248536
# min                0.000000  ...             1.000000     1.000000
# 25%                1.000000  ...             1.000000     1.000000
# 50%                1.000000  ...             1.000000     1.000000
# 75%                1.000000  ...             1.000000     1.000000
# max                4.000000  ...             9.000000     5.000000
#
#          FenceIND  FenceConditionID     SignIND  SignConditionID  \
# count  487.000000        237.000000  439.000000       280.000000
# mean     0.486653          3.603376    0.637813         1.257143
# std      0.500336          0.975803    0.481181         1.073442
# min      0.000000          1.000000    0.000000         1.000000
# 25%      0.000000          4.000000    0.000000         1.000000
# 50%      0.000000          4.000000    1.000000         1.000000
# 75%      1.000000          4.000000    1.000000         1.000000
# max      1.000000          4.000000    1.000000         7.000000
#
#        PointOfEntryID  DistanceToCrossing_Miles  TrespasserVehicleInvolvedInd  \
# count      400.000000                441.000000                   1496.000000
# mean         3.195000                  0.341950                      0.110294
# std          2.181484                  2.108173                      0.313361
# min          1.000000                  0.000000                      0.000000
# 25%          1.000000                  0.100000                      0.000000
# 50%          4.000000                  0.100000                      0.000000
# 75%          5.000000                  0.300000                      0.000000
# max          6.000000                 43.500000                      1.000000
#
#        TrespasserVehicleTypeID
# count               165.000000
# mean                  9.666667
# std                   5.296494
# min                   4.000000
# 25%                   4.000000
# 50%                   7.000000
# 75%                  15.000000
# max                  17.000000
#
# [8 rows x 179 columns]

# %%
railDataEnglish.nunique()
# Out:
# OccID                              59928
# OccNo                              59928
# OccClassID                            11
# OccClassID_DisplayEng                 10
# OccDate                            24228
#                                    ...
# PointOfEntryID_DisplayEng              5
# DistanceToCrossing_Miles              18
# TrespasserVehicleInvolvedInd           2
# TrespasserVehicleTypeID               11
# TrespasserVehicleTypeDisplayEng       11
# Length: 276, dtype: int64

# %%
railDataEnglish.isna().sum()
# Out:
# OccID                                  0
# OccNo                                  0
# OccClassID                             0
# OccClassID_DisplayEng              11572
# OccDate                                0
#                                    ...
# PointOfEntryID_DisplayEng          65939
# DistanceToCrossing_Miles           65898
# TrespasserVehicleInvolvedInd       64843
# TrespasserVehicleTypeID            66174
# TrespasserVehicleTypeDisplayEng    66174
# Length: 276, dtype: int64

# %%
railDataEnglish[railDataEnglish.duplicated('OccID',keep=False)]
# Out:
#         OccID     OccNo  OccClassID OccClassID_DisplayEng  \
# 36     132813  R22V0239           5                     5
# 37     132813  R22V0239           5                     5
# 234    132603  R22V0207           5                     5
# 235    132603  R22V0207           5                     5
# 301    132534  R22D0089           5                     5
# ...       ...       ...         ...                   ...
# 54559   40133  R90V0392           9                   C-4
# 54560   40133  R90V0392           9                   C-4
# 54763   39926  R90T0124           8                   C-3
# 54764   39926  R90T0124           8                   C-3
# 54765   39926  R90T0124           8                   C-3
#
#                       OccDate  OccYear  OccTime  TimeZoneID  \
# 36     12/30/2022 10:40:00 AM     2022   1040.0         7.0
# 37     12/30/2022 10:40:00 AM     2022   1040.0         7.0
# 234      11/6/2022 5:15:00 AM     2022    515.0         7.0
# 235      11/6/2022 5:15:00 AM     2022    515.0         7.0
# 301      10/8/2022 6:20:00 PM     2022   1820.0         4.0
# ...                       ...      ...      ...         ...
# 54559  10/20/1990 12:00:00 AM     1990   1900.0         7.0
# 54560  10/20/1990 12:00:00 AM     1990   1900.0         7.0
# 54763   4/24/1990 12:00:00 AM     1990      0.0         2.0
# 54764   4/24/1990 12:00:00 AM     1990      0.0         2.0
# 54765   4/24/1990 12:00:00 AM     1990      0.0         2.0
#
#       TimeZoneID_DisplayEng  OccurrenceTypeID  ...  \
# 36                      PST                 1  ...
# 37                      PST                 1  ...
# 234                     PST                 1  ...
# 235                     PST                 1  ...
# 301                     EDT                 3  ...
# ...                     ...               ...  ...
# 54559                   PST                 1  ...
# 54560                   PST                 1  ...
# 54763                   EST                 1  ...
# 54764                   EST                 1  ...
# 54765                   EST                 1  ...
#
#       FenceConditionID_DisplayEng  SignIND SignConditionID  \
# 36                            NaN      NaN             NaN
# 37                            NaN      NaN             NaN
# 234                           NaN      NaN             NaN
# 235                           NaN      NaN             NaN
# 301                           NaN      NaN             NaN
# ...                           ...      ...             ...
# 54559                         NaN      NaN             NaN
# 54560                         NaN      NaN             NaN
# 54763                         NaN      NaN             NaN
# 54764                         NaN      NaN             NaN
# 54765                         NaN      NaN             NaN
#
#        SignConditionID_DisplayEng PointOfEntryID  PointOfEntryID_DisplayEng  \
# 36                            NaN            NaN                        NaN
# 37                            NaN            NaN                        NaN
# 234                           NaN            NaN                        NaN
# 235                           NaN            NaN                        NaN
# 301                           NaN            NaN                        NaN
# ...                           ...            ...                        ...
# 54559                         NaN            NaN                        NaN
# 54560                         NaN            NaN                        NaN
# 54763                         NaN            NaN                        NaN
# 54764                         NaN            NaN                        NaN
# 54765                         NaN            NaN                        NaN
#
#       DistanceToCrossing_Miles  TrespasserVehicleInvolvedInd  \
# 36                         0.0                           0.0
# 37                         0.0                           0.0
# 234                        NaN                           NaN
# 235                        NaN                           NaN
# 301                        NaN                           NaN
# ...                        ...                           ...
# 54559                      NaN                           NaN
# 54560                      NaN                           NaN
# 54763                      NaN                           NaN
# 54764                      NaN                           NaN
# 54765                      NaN                           NaN
#
#        TrespasserVehicleTypeID TrespasserVehicleTypeDisplayEng
# 36                         NaN                             NaN
# 37                         NaN                             NaN
# 234                        NaN                             NaN
# 235                        NaN                             NaN
# 301                        NaN                             NaN
# ...                        ...                             ...
# 54559                      NaN                             NaN
# 54560                      NaN                             NaN
# 54763                      NaN                             NaN
# 54764                      NaN                             NaN
# 54765                      NaN                             NaN
#
# [11096 rows x 276 columns]

# %%
railDataEnglish.drop_duplicates(subset=['OccID'],keep='first',inplace=True)

# %%
railDataEnglish.shape
# Out:
# (59928, 276)

# %%
railDataEnglish.isna().sum()
# Out:
# OccID                                  0
# OccNo                                  0
# OccClassID                             0
# OccClassID_DisplayEng              11572
# OccDate                                0
#                                    ...
# PointOfEntryID_DisplayEng          59555
# DistanceToCrossing_Miles           59512
# TrespasserVehicleInvolvedInd       58500
# TrespasserVehicleTypeID            59779
# TrespasserVehicleTypeDisplayEng    59779
# Length: 276, dtype: int64

# %%
railDataEnglish['OccDate'] = pd.to_datetime(railDataEnglish['OccDate'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')
railDataEnglish['OccDate'] = pd.to_datetime(railDataEnglish['OccDate'], format='%m-%d-%Y %H:%M', errors='coerce')
railDataEnglish['OccDate'] = pd.to_datetime(railDataEnglish['OccDate'], format='%Y-%m-%d', errors='coerce')

# %%
railDataEnglish.head()
# Out:
#     OccID     OccNo  OccClassID OccClassID_DisplayEng             OccDate  \
# 0  132852  R23S0008           5                     5 2023-01-07 06:50:00
# 1  132851  R23W0005           5                     5 2023-01-09 06:49:00
# 2  132850  R23V0005           5                     5 2023-01-09 15:35:00
# 3  132849  R23C0001           5                     5 2023-01-05 23:43:00
# 4  132848  R23W0004           5                     5 2023-01-08 17:55:00
#
#    OccYear  OccTime  TimeZoneID TimeZoneID_DisplayEng  OccurrenceTypeID  ...  \
# 0     2023    650.0        11.0                   CST                 1  ...
# 1     2023    649.0        11.0                   CST                 1  ...
# 2     2023   1535.0         7.0                   PST                 3  ...
# 3     2023   2343.0        10.0                   MST                 1  ...
# 4     2023   1755.0        11.0                   CST                 1  ...
#
#   FenceConditionID_DisplayEng  SignIND SignConditionID  \
# 0                         NaN      NaN             NaN
# 1                         NaN      NaN             NaN
# 2                         NaN      NaN             NaN
# 3                         NaN      NaN             NaN
# 4                         NaN      NaN             NaN
#
#    SignConditionID_DisplayEng PointOfEntryID  PointOfEntryID_DisplayEng  \
# 0                         NaN            NaN                        NaN
# 1                         NaN            NaN                        NaN
# 2                         NaN            NaN                        NaN
# 3                         NaN            NaN                        NaN
# 4                         NaN            NaN                        NaN
#
#   DistanceToCrossing_Miles  TrespasserVehicleInvolvedInd  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#    TrespasserVehicleTypeID TrespasserVehicleTypeDisplayEng
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
# [5 rows x 276 columns]

# %%
railDataEnglish[railDataEnglish['ActivityTypeID_DisplayEng'].isnull()]
# Out:
#         OccID     OccNo  OccClassID OccClassID_DisplayEng    OccDate  OccYear  \
# 20453  110411  R07H0227           5                     5 2007-09-04     2007
# 20454  110410  R07H0226           5                     5 2007-09-01     2007
# 20456  110407  R07H0223           5                     5 2007-10-17     2007
# 20457  110406  R07H0222           5                     5 2007-10-17     2007
# 20458  110405  R07H0221           5                     5 2007-10-13     2007
# ...       ...       ...         ...                   ...        ...      ...
# 23076  106945  R05H0036           5                     5 2005-12-03     2005
# 23077  106944  R06H0019           5                     5 2006-03-31     2006
# 23078  106943  R03H0006           5                     5 2003-10-16     2003
# 23079  106942  R05H0035           5                     5 2005-05-12     2005
# 24629  105308  R06T0140           5                     5 2006-07-03     2006
#
#        OccTime  TimeZoneID TimeZoneID_DisplayEng  OccurrenceTypeID  ...  \
# 20453    843.0         NaN                   NaN                 1  ...
# 20454   2230.0         NaN                   NaN                 1  ...
# 20456   1500.0         NaN                   NaN                 1  ...
# 20457    945.0         NaN                   NaN                 1  ...
# 20458    400.0         NaN                   NaN                 1  ...
# ...        ...         ...                   ...               ...  ...
# 23076   1545.0         NaN                   NaN                 1  ...
# 23077     20.0         NaN                   NaN                 1  ...
# 23078   1120.0         NaN                   NaN                 1  ...
# 23079      1.0         NaN                   NaN                 1  ...
# 24629   2325.0         4.0                   EDT                 3  ...
#
#       FenceConditionID_DisplayEng  SignIND SignConditionID  \
# 20453                         NaN      NaN             NaN
# 20454                         NaN      NaN             NaN
# 20456                         NaN      NaN             NaN
# 20457                         NaN      NaN             NaN
# 20458                         NaN      NaN             NaN
# ...                           ...      ...             ...
# 23076                         NaN      NaN             NaN
# 23077                         NaN      NaN             NaN
# 23078                         NaN      NaN             NaN
# 23079                         NaN      NaN             NaN
# 24629                         NaN      NaN             NaN
#
#        SignConditionID_DisplayEng PointOfEntryID  PointOfEntryID_DisplayEng  \
# 20453                         NaN            NaN                        NaN
# 20454                         NaN            NaN                        NaN
# 20456                         NaN            NaN                        NaN
# 20457                         NaN            NaN                        NaN
# 20458                         NaN            NaN                        NaN
# ...                           ...            ...                        ...
# 23076                         NaN            NaN                        NaN
# 23077                         NaN            NaN                        NaN
# 23078                         NaN            NaN                        NaN
# 23079                         NaN            NaN                        NaN
# 24629                         NaN            NaN                        NaN
#
#       DistanceToCrossing_Miles  TrespasserVehicleInvolvedInd  \
# 20453                      NaN                           NaN
# 20454                      NaN                           NaN
# 20456                      NaN                           NaN
# 20457                      NaN                           NaN
# 20458                      NaN                           NaN
# ...                        ...                           ...
# 23076                      NaN                           NaN
# 23077                      NaN                           NaN
# 23078                      NaN                           NaN
# 23079                      NaN                           NaN
# 24629                      NaN                           NaN
#
#        TrespasserVehicleTypeID TrespasserVehicleTypeDisplayEng
# 20453                      NaN                             NaN
# 20454                      NaN                             NaN
# 20456                      NaN                             NaN
# 20457                      NaN                             NaN
# 20458                      NaN                             NaN
# ...                        ...                             ...
# 23076                      NaN                             NaN
# 23077                      NaN                             NaN
# 23078                      NaN                             NaN
# 23079                      NaN                             NaN
# 24629                      NaN                             NaN
#
# [1742 rows x 276 columns]

# %%
railDataEnglish['ActivityTypeID_DisplayEng'].isnull().sum()
# Out:
# 1742

# %%
railDataEnglish['ActivityTypeID'].isnull().sum()
# Out:
# 1742

# %%
railDataEnglish['ActivityTypeID'].unique()
# Out:
# array([11.,  4., 14., 16., 12., 13., 10., 15.,  2.,  7.,  9.,  3., 19.,
#         6.,  5.,  1., 17.,  8., nan])

# %%
railDataEnglish['ActivityTypeID_DisplayEng'].unique()
# Out:
# array(['SWITCHING', 'PROCEEDING', 'SWITCHING PULLING',
#        'SWITCHING COUPLING', 'SWITCHING HUMPING', 'SWITCHING SPOTTING',
#        'STANDING', 'SWITCHING SHOVING', 'MAINTENANCE', 'REVERSING',
#        'REVERSING DECELERATING', 'UNCONTROLLED', 'UNKNOWN',
#        'PROCEEDING DECELERATING', 'PROCEEDING ACCELERATING', 'INSPECTION',
#        'PROCEEDING AFTER COLLISION', 'REVERSING ACCELERATING', nan],
#       dtype=object)

# %%
railDataEnglish.loc[railDataEnglish['ActivityTypeID_DisplayEng'] == 'UNKNOWN', 'ActivityTypeID':'ActivityTypeID_DisplayEng']
# Out:
#        ActivityTypeID ActivityTypeID_DisplayEng
# 161              19.0                   UNKNOWN
# 261              19.0                   UNKNOWN
# 349              19.0                   UNKNOWN
# 391              19.0                   UNKNOWN
# 393              19.0                   UNKNOWN
# ...               ...                       ...
# 66315            19.0                   UNKNOWN
# 66319            19.0                   UNKNOWN
# 66322            19.0                   UNKNOWN
# 66327            19.0                   UNKNOWN
# 66332            19.0                   UNKNOWN
#
# [1363 rows x 2 columns]

# %%
railDataEnglish['ActivityTypeID'] = railDataEnglish['ActivityTypeID'].fillna(19.0)

# %%
railDataEnglish['ActivityTypeID']
# Out:
# 0        11.0
# 1         4.0
# 2         4.0
# 3         4.0
# 4         4.0
#          ...
# 66334     3.0
# 66335     4.0
# 66336     4.0
# 66337     4.0
# 66338     4.0
# Name: ActivityTypeID, Length: 59928, dtype: float64

# %%
railDataEnglish['ActivityTypeID'].unique()
# Out:
# array([11.,  4., 14., 16., 12., 13., 10., 15.,  2.,  7.,  9.,  3., 19.,
#         6.,  5.,  1., 17.,  8.])

# %%
railDataEnglish['ActivityTypeID_DisplayEng'].unique()
# Out:
# array(['SWITCHING', 'PROCEEDING', 'SWITCHING PULLING',
#        'SWITCHING COUPLING', 'SWITCHING HUMPING', 'SWITCHING SPOTTING',
#        'STANDING', 'SWITCHING SHOVING', 'MAINTENANCE', 'REVERSING',
#        'REVERSING DECELERATING', 'UNCONTROLLED', 'UNKNOWN',
#        'PROCEEDING DECELERATING', 'PROCEEDING ACCELERATING', 'INSPECTION',
#        'PROCEEDING AFTER COLLISION', 'REVERSING ACCELERATING', nan],
#       dtype=object)

# %%
railDataEnglish['ActivityTypeID_DisplayEng'].fillna(value='UNKNOWN', inplace=True)

# %%
railDataEnglish['ActivityTypeID_DisplayEng'].unique()
# Out:
# array(['SWITCHING', 'PROCEEDING', 'SWITCHING PULLING',
#        'SWITCHING COUPLING', 'SWITCHING HUMPING', 'SWITCHING SPOTTING',
#        'STANDING', 'SWITCHING SHOVING', 'MAINTENANCE', 'REVERSING',
#        'REVERSING DECELERATING', 'UNCONTROLLED', 'UNKNOWN',
#        'PROCEEDING DECELERATING', 'PROCEEDING ACCELERATING', 'INSPECTION',
#        'PROCEEDING AFTER COLLISION', 'REVERSING ACCELERATING'],
#       dtype=object)

# %%
railDataEnglish.loc[railDataEnglish['ActivityTypeID_DisplayEng'] == 'UNKNOWN', 'ActivityTypeID':'ActivityTypeID_DisplayEng']
# Out:
#        ActivityTypeID ActivityTypeID_DisplayEng
# 161              19.0                   UNKNOWN
# 261              19.0                   UNKNOWN
# 349              19.0                   UNKNOWN
# 391              19.0                   UNKNOWN
# 393              19.0                   UNKNOWN
# ...               ...                       ...
# 66315            19.0                   UNKNOWN
# 66319            19.0                   UNKNOWN
# 66322            19.0                   UNKNOWN
# 66327            19.0                   UNKNOWN
# 66332            19.0                   UNKNOWN
#
# [3105 rows x 2 columns]

# %%
print(railDataEnglish.dtypes)
# Out:
# OccID                                       int64
# OccNo                                      object
# OccClassID                                  int64
# OccClassID_DisplayEng                      object
# OccDate                            datetime64[ns]
#                                         ...
# PointOfEntryID_DisplayEng                  object
# DistanceToCrossing_Miles                  float64
# TrespasserVehicleInvolvedInd              float64
# TrespasserVehicleTypeID                   float64
# TrespasserVehicleTypeDisplayEng            object
# Length: 276, dtype: object

# %%
object_cols = railDataEnglish.select_dtypes(include='object').columns
railDataEnglish[object_cols] = railDataEnglish[object_cols].astype('category')

# %%
print(railDataEnglish.dtypes)
# Out:
# OccID                                       int64
# OccNo                                    category
# OccClassID                                  int64
# OccClassID_DisplayEng                    category
# OccDate                            datetime64[ns]
#                                         ...
# PointOfEntryID_DisplayEng                category
# DistanceToCrossing_Miles                  float64
# TrespasserVehicleInvolvedInd              float64
# TrespasserVehicleTypeID                   float64
# TrespasserVehicleTypeDisplayEng          category
# Length: 276, dtype: object

# %% [markdown]
# What is the overall trend in the number of railway occurrences reported over the years

# %%
# Set figure size
plt.figure(figsize=(12,6))
grouped_data = railDataEnglish.groupby(railDataEnglish['OccYear'])['OccID'].count()

# plot the trend in a line chart
plt.plot(grouped_data.index, grouped_data.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Number of occurrences')
plt.title('Trend in Railway Occurrences Reported over the Years')
plt.show()

# %%
# Group data by activity type and calculate the total number of trains involved
activity_grouped = railDataEnglish.groupby('ActivityTypeID_DisplayEng')['TotalRSInvolved'].sum()

# Create a bar chart
plt.bar(activity_grouped.index, activity_grouped.values)
plt.xticks(rotation=90)
plt.xlabel('Activity Type')
plt.ylabel('Total Trains Involved')
plt.title('Number of Trains Involved by Activity Type')
plt.show()

# %% [markdown]
# What is the distribution of the severity levels of railway occurrences in the dataset?

# %%
# Filter for occurrences with property damage or injuries
filtered_data = railDataEnglish[(railDataEnglish['AccIncTypeID_DisplayEng'] == 'Property damage') | (railDataEnglish['InjuriesIND'] == True)]

# Plot the distribution of injuries by type
plt.figure(figsize=(10, 5))
injury_cols = ['TotalFatalInjuries', 'TotalSeriousInjuries', 'TotalMinorInjuries', 'TotalEmployeeInjuries', 'TotalPassengerInjuries', 'TotalOtherInjuries', 'TotalMotorVehicleInjuries', 'TotalPedestrianInjuries', 'TotalTrespasserInjuries']
injury_data = filtered_data[injury_cols].sum().reset_index(name='count')
sns.barplot(x='index', y='count', data=injury_data)
plt.title('Distribution of Injuries by Type')
plt.xlabel('Injury Type')
plt.xticks(rotation=90)

plt.ylabel('Count')
plt.show()

# %% [markdown]
# What is the most common type of railway occurrence reported in the dataset?

# %%
# Group the data by Occurrence Type and count the number of occurrences
occurrence_counts = railDataEnglish.groupby('OccurrenceTypeID_DisplayEng')['OccID'].count()

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 6))
colors = ['b', 'g']
ax.bar(occurrence_counts.index, occurrence_counts.values, color=colors, alpha=0.7)

# Set the title and axis labels
ax.set_title('Number of Occurrences by Type')
ax.set_xlabel('Occurrence Type')
ax.set_ylabel('Number of Occurrences')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add data labels to the bars
for i, v in enumerate(occurrence_counts.values):
    ax.text(i, v + 50, str(v), ha='center')

# Show the plot
plt.show()

# %% [markdown]
# Is there a correlation between the time of day and the frequency of railway occurrences reported?

# %%
railDataEnglish['OccTime'] = railDataEnglish['OccTime'].fillna(0)

# %%
railDataEnglish['OccTime'] = railDataEnglish['OccTime'].astype(int)

# %%
def time_of_day_category(time):
    if 0 <= time < 600:
        return 'Night'
    elif 600 <= time < 1200:
        return 'Morning'
    elif 1200 <= time < 1800:
        return 'Afternoon'
    else:
        return 'Evening'

railDataEnglish['OccTimeCategory'] = railDataEnglish['OccTime'].apply(time_of_day_category)

# %%
railDataEnglish['OccTimeCategory']
# Out:
# 0          Morning
# 1          Morning
# 2        Afternoon
# 3          Evening
# 4        Afternoon
#            ...
# 66334        Night
# 66335      Morning
# 66336    Afternoon
# 66337    Afternoon
# 66338    Afternoon
# Name: OccTimeCategory, Length: 59928, dtype: object

# %%
# Create a groupby object by hour of day and count the occurrences
hourly_occurrences = railDataEnglish.groupby(railDataEnglish['OccTimeCategory'])['OccurrenceTypeID'].count()

# Set the plot size
plt.figure(figsize=(12, 6))

# Plot the data as a bar plot
sns.barplot(x=hourly_occurrences.index, y=hourly_occurrences.values)

# Set the plot title and axis labels
plt.title('Frequency of railway occurrences by hour of day', fontsize=16)
plt.xlabel('Hour of day', fontsize=14)
plt.ylabel('Number of occurrences', fontsize=14)

# Rotate the x-axis labels to avoid overlapping text
plt.xticks(rotation=45)

# Add a grid to the plot
plt.grid(axis='y', alpha=0.5)

# Show the plot
plt.show()

# %% [markdown]
# What is the average number of trains and train cars involved in railway occurrences? How does this vary by type of occurrence?

# %%
# Calculate the average number of trains and train cars involved by occurrence type
occurrence_types = railDataEnglish["OccurrenceTypeID_DisplayEng"].unique()
results = []
for occurrence_type in occurrence_types:
    subset = railDataEnglish[railDataEnglish["OccurrenceTypeID_DisplayEng"] == occurrence_type]
    avg_trains = subset["NumberTrainsInvolved"].mean()
    avg_rs_cars = subset["TotalRSInvolved"].mean()
    avg_dg_cars = subset["TotalDGCarsInvolved"].mean()
    results.append((occurrence_type, avg_trains, avg_rs_cars, avg_dg_cars))

# Convert the results to a dataframe and display it
results_df = pd.DataFrame(results, columns=["Occurrence Type", "Avg Trains Involved", "Avg RS Cars Involved", "Avg DG Cars Involved"])
print(results_df)
# Out:
#   Occurrence Type  Avg Trains Involved  Avg RS Cars Involved  \
# 0        ACCIDENT             1.097832              1.834176
# 1        INCIDENT             1.015333              0.754673
#
#    Avg DG Cars Involved
# 0              0.677631
# 1              0.764722

# %% [markdown]
#  How does the severity level of railway occurrences reported differ between different types of equipment or machinery involved?

# %%
# Group the data by the equipment/machinery involved and calculate the average severity level for each group
severity_by_equipment = railDataEnglish.groupby('ActivityTypeID_DisplayEng')['InjuriesIND', 'TotalFatalInjuries', 'TotalSeriousInjuries', 'TotalMinorInjuries'].mean()

# Print the results
print(severity_by_equipment)
# Out:
#                             InjuriesIND  TotalFatalInjuries  \
# ActivityTypeID_DisplayEng
# INSPECTION                     0.011512            0.001291
# MAINTENANCE                    0.085938            0.010178
# PROCEEDING                     0.429505            0.128419
# PROCEEDING ACCELERATING        0.213592            0.048780
# PROCEEDING AFTER COLLISION     0.400000            0.111111
# PROCEEDING DECELERATING        0.140625            0.023490
# REVERSING                      0.077295            0.007924
# REVERSING ACCELERATING         0.250000            0.000000
# REVERSING DECELERATING         0.153846            0.000000
# STANDING                       0.179941            0.001051
# SWITCHING                      0.033299            0.002651
# SWITCHING COUPLING             0.046477            0.002743
# SWITCHING HUMPING              0.024470            0.001161
# SWITCHING PULLING              0.023574            0.002836
# SWITCHING SHOVING              0.036826            0.003605
# SWITCHING SPOTTING             0.044369            0.004184
# UNCONTROLLED                   0.052566            0.057597
# UNKNOWN                        0.120553            0.020290
#
#                             TotalSeriousInjuries  TotalMinorInjuries
# ActivityTypeID_DisplayEng
# INSPECTION                              0.000968            0.010652
# MAINTENANCE                             0.040712            0.053435
# PROCEEDING                              0.072066            0.239911
# PROCEEDING ACCELERATING                 0.121951            0.016260
# PROCEEDING AFTER COLLISION              0.166667            0.111111
# PROCEEDING DECELERATING                 0.030201            0.124161
# REVERSING                               0.019810            0.168780
# REVERSING ACCELERATING                  0.117647            0.117647
# REVERSING DECELERATING                  0.133333            0.066667
# STANDING                                0.009982            0.034326
# SWITCHING                               0.008361            0.018148
# SWITCHING COUPLING                      0.028807            0.038409
# SWITCHING HUMPING                       0.003484            0.019744
# SWITCHING PULLING                       0.006931            0.025520
# SWITCHING SHOVING                       0.009833            0.022943
# SWITCHING SPOTTING                      0.016736            0.016736
# UNCONTROLLED                            0.005958            0.049652
# UNKNOWN                                 0.003865            0.145894
# <ipython-input-143-57ab8db6e7eb>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   severity_by_equipment = railDataEnglish.groupby('ActivityTypeID_DisplayEng')['InjuriesIND', 'TotalFatalInjuries', 'TotalSeriousInjuries', 'TotalMinorInjuries'].mean()

# %% [markdown]
# What is the percentage of railway occurrences that involve hazardous materials or dangerous goods? How does this vary by region or type of occurrence?

# %%
dg_released = railDataEnglish[railDataEnglish['DGReleasedCarsIND'] == 1]

# calculate the percentage of rows with dangerous goods released
dg_percent = len(dg_released) / len(railDataEnglish) * 100

# group the data by region and calculate the percentage for each region
dg_by_region = dg_released.groupby('RegionOfOccurrence')['DGReleasedCarsIND'].count() / railDataEnglish.groupby('RegionOfOccurrence')['OccNo'].count() * 100

# group the data by type of occurrence and calculate the percentage for each type
dg_by_occurrence = dg_released.groupby('OccurrenceTypeID_DisplayEng')['DGReleasedCarsIND'].count() / railDataEnglish.groupby('OccurrenceTypeID_DisplayEng')['OccNo'].count() * 100

# print the results
print(f"Percentage of railway occurrences involving dangerous goods: {dg_percent:.2f}%")
print("\nPercentage by region:")
print(dg_by_region)
print("\nPercentage by type of occurrence:")
print(dg_by_occurrence)
# Out:
# Percentage of railway occurrences involving dangerous goods: 0.27%
#
# Percentage by region:
# RegionOfOccurrence
# 20.0    0.278379
# 24.0         NaN
# 44.0    0.439422
# 45.0    0.378947
# 46.0    0.257913
# 47.0    0.437367
# 48.0    0.235627
# 49.0    0.309314
# 50.0    0.521069
# 51.0    0.453760
# 52.0    0.089629
# 54.0    0.790514
# dtype: float64
#
# Percentage by type of occurrence:
# OccurrenceTypeID_DisplayEng
# ACCIDENT    0.339726
# INCIDENT    0.034958
# dtype: float64

# %% [markdown]
# Which railway companies or sub-divisions have the highest number of occurrences reported?

# %%
# Group the occurrences by sub-division owner and count the number of occurrences reported for each
occurrences_by_owner = railDataEnglish.groupby("SubdOwnerID_DisplayEng")["OccNo"].count()

# Sort the sub-division owners by the number of occurrences reported in descending order
occurrences_by_owner = occurrences_by_owner.sort_values(ascending=False)

# Print the top 10 sub-division owners with the highest number of occurrences reported
print(occurrences_by_owner.head(10))
# Out:
# SubdOwnerID_DisplayEng
# CN - CANADIAN NATIONAL RAILWAY CO.             32140
# CP - CANADIAN PACIFIC RAILWAY CO.              23778
# QUEBEC NORTH SHORE AND LABRADOR RAILWAY CO.      672
# CSX TRANSPORTATION                               442
# HUDSON BAY RAILWAY                               315
# VIA RAIL CANADA INC.                             247
# GODERICH-EXETER RAILWAY COMPANY LTD.             207
# BURLINGTON NORTHERN RAILROAD CO.                 202
# MONTREAL,  MAINE & ATLANTIC RAILWAY              161
# GO - METROLINX                                   150
# Name: OccNo, dtype: int64
